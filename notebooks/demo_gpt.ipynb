# %% [markdown]
# # SocraticGPT-3

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal of this jupyter notebook is to run the Socratic Models paper with the GPT-3 (Davinci-2) model.

# %% [markdown]
# ## Imports

# %%
# Package loading
from transformers import set_seed
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Local imports
import sys

sys.path.append('..')
try:
    os.chdir('scripts')
except:
    pass

from scripts.coco_captioning_gpt import ImageCaptionerGPT

# %% [markdown]
# ## Instantiate the improved captioner class

# %%
image_captioner = ImageCaptionerGPT(set_type='demo')
# Out:
# load_places starting!
# load_places took 0.0s!
# load_objects starting!
# load_objects took 0.0s!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Run main

# %%
image_captioner.main()
# Out:
# main starting!
# main took 47.0s!

# %% [markdown]
# ## Load image and compute image embedding

# %%
image_folder = '../data/images/example_images/'
# Show the image
for img_name in image_captioner.image_manager.demo_names:
    print(f'{img_name}:')
    plt.imshow(image_captioner.image_manager.load_image(image_folder + img_name))
    plt.show()
    cond = image_captioner.generated_caption_df['image_name'] == img_name
    generate_caption = image_captioner.generated_caption_df[cond]['generated_caption'].iloc[0]
    print(f'generate caption: "{generate_caption}"\n')
    print('====================================\n')
# Out:
# demo_img.png:
# generate caption: "The indoor bow window is a great spot to enjoy your meals."
#
# ====================================
#
# monkey_with_gun.jpg:
# generate caption: ""A chimp at a vet's office.""
#
# ====================================
#
# astronaut_with_beer.jpg:
# generate caption: ""A photo of a spaceman enjoying a beer.""
#
# ====================================
#
# fruit_bowl.jpg:
# generate caption: "Aerial view of a supermarket dish rack"
#
# ====================================
#
# cute_bear.jpg:
# generate caption: ""A Bear's True Love""
#
# ====================================
#
# wedding_image.jpg:
# generate caption: ""A beautiful forest path, promenade or field road photo with a dress suit.""
#
# ====================================
